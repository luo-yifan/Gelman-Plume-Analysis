# %%
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from autots import AutoTS
import pathlib

# %%
well_data = pd.read_excel('../data/Data-Wells.xlsx')
s =  well_data['Well Name'] == '110 Parkland Plaza'
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-b1d09d6ee56d> in <module>
# ----> 1 well_data = pd.read_excel('../data/Data-Wells.xlsx')
#       2 s =  well_data['Well Name'] == '110 Parkland Plaza'
#
# ~/.virtualenvs/Gelman-Plume-Analysis/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ...

# %%
res = well_data[s]
res

# %%
res.to_excel("./110_Parkland_Plaza.xlsx")

# %%
rr = pd.read_excel("./110_Parkland_Plaza.xlsx")
rr
# Out:
#     Unnamed: 0  Sample ID           Well Name   Entered  \
# 0           16         57  110 Parkland Plaza       NaN
# 1           17         58  110 Parkland Plaza       NaN
# 2           18         61  110 Parkland Plaza       NaN
# 3           19         62  110 Parkland Plaza       NaN
# 4           20        187  110 Parkland Plaza       NaN
# 5           21        188  110 Parkland Plaza       NaN
# 6           22        249  110 Parkland Plaza       NaN
# 7           23        301  110 Parkland Plaza       NaN
# 8           24        402  110 Parkland Plaza       NaN
# 9           25        496  110 Parkland Plaza       NaN
# 10          26        618  110 Parkland Plaza       NaN
# 11          27        716  110 Parkland Plaza       NaN
# 12          28        774  110 Parkland Plaza       NaN
# 13          29        901  110 Parkland Plaza       NaN
# 14          30        970  110 Parkland Plaza       NaN
# 15          31       1082  110 Parkland Plaza       NaN
# ...

# %%
start_year = 20
start_dio  = 20
fake = pd.DataFrame(columns=rr.columns)

list = []
for index, row in rr.iterrows():
    row['Date Sampled'] = "01/01/" + str(start_year)
    row['1,4-Dioxane Results (ppb)'] = start_dio
    print(type(row))
    fake.append(row, ignore_index=True)
    list.append(row)
    start_year = start_year + 1
    start_dio = start_dio + 5

fake
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# ...

# %%
list
df=pd.DataFrame(list[0:10],columns=rr.columns)
df
# Out:
#    Unnamed: 0  Sample ID           Well Name  Entered  \
# 0          16         57  110 Parkland Plaza      NaN
# 1          17         58  110 Parkland Plaza      NaN
# 2          18         61  110 Parkland Plaza      NaN
# 3          19         62  110 Parkland Plaza      NaN
# 4          20        187  110 Parkland Plaza      NaN
# 5          21        188  110 Parkland Plaza      NaN
# 6          22        249  110 Parkland Plaza      NaN
# 7          23        301  110 Parkland Plaza      NaN
# 8          24        402  110 Parkland Plaza      NaN
# 9          25        496  110 Parkland Plaza      NaN
#
#    1,4-Dioxane Results (ppb) Date Sampled  Time Sampled  Date Received  \
# 0                         20     01/01/20           NaN            NaN
# 1                         25     01/01/21           NaN            NaN
# 2                         30     01/01/22           NaN            NaN
# 3                         35     01/01/23           NaN            NaN
# ...

# %%
df.to_excel("./110_Parkland_Plaza_predict.xlsx")
