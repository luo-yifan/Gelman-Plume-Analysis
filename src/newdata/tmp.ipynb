# %%
import pathlib

import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt

# %%
gelman_data = pd.read_excel("../../result/history/result(new)/joined_well_data.xlsx")
gelman_data.head(5)
# Out:
#    Unnamed: 0               Bore         Name  Depth1  Depth2 SampleDate  \
# 0           0  1021 Westview Way  1-4 Dioxane   260.0   268.0 2019-05-08
# 1           1  1024 Westview Way  1-4 Dioxane -9999.0 -9999.0 2019-05-08
# 2           2  1049 Westview Way  1-4 Dioxane   272.0   280.0 2019-05-08
# 3           3         105 Myrtle  1-4 Dioxane    61.0    65.0 1999-03-27
# 4           4         105 Myrtle  1-4 Dioxane    61.0    65.0 1999-05-28
#
#    Value   Comment  Enabled     Easting  ...  utm_datum  utm_zone  utm_x  \
# 0    0.5  EGLE Lab    False  13274717.9  ...         22        12      0
# 1    0.5  EGLE Lab    False  13274221.6  ...         22        12      0
# 2    0.5  EGLE Lab    False  13274722.1  ...         22        12      0
# 3    0.5       NaN    False  13269250.0  ...         22        12      0
# 4    0.5       NaN    False  13269250.0  ...         22        12      0
#
#    utm_y utm_unit  pj4_x  pj4_y  pj4_paramstr        lat        lon
# ...

# %%
gelman_data.columns
# Out:
# Index(['Unnamed: 0', 'Bore', 'Name', 'Depth1', 'Depth2', 'SampleDate', 'Value',
#        'Comment', 'Enabled', 'Easting', 'Northing', 'Elevation', 'TotalDepth',
#        'CollarElevation', 'Comments', 'GEIcon', 'Color', 'SymbolTypeId',
#        'NeedXYZCalc', 'dd_lon', 'dd_lat', 'lcs_x', 'lcs_y', 'lcs_unit',
#        'pls_meridian', 'pls_range', 'pls_township', 'pls_section',
#        'pls_offset_based', 'pls_x_offset', 'pls_y_offset', 'pls_fwl',
#        'pls_fsl', 'pls_description', 'spc_zone', 'spc_x', 'spc_y', 'spc_unit',
#        'utm_datum', 'utm_zone', 'utm_x', 'utm_y', 'utm_unit', 'pj4_x', 'pj4_y',
#        'pj4_paramstr', 'lat', 'lon'],
#       dtype='object')

# %%
well_name_list = list(dict.fromkeys(gelman_data['Bore'].tolist()))
well_name_list[0:10]
# Out:
# ['1021 Westview Way',
#  '1024 Westview Way',
#  '1049 Westview Way',
#  '105 Myrtle',
#  '1052 Westview Way',
#  '1080 Westview Way',
#  '110 Parkland Plaza',
#  '1105 Westview Way',
#  '1108 Westview Way',
#  '1130 Westview Way']

# %%
res = {}
for well_name in well_name_list:
    var = gelman_data.loc[gelman_data['Bore'] == well_name]
    years_max = {}
    for y in range(1986, 2020):
        for index, row in var.iterrows():
            if row['SampleDate'].year == y:
                if years_max.get(y) is not None:
                    if years_max[y] < row['Value']:
                        years_max[y] = row['Value']
                else:
                    years_max[y] = row['Value']
    res[well_name] = years_max
print(res)
# Out:
# {'1021 Westview Way': {2019: 0.5}, '1024 Westview Way': {2019: 0.5}, '1049 Westview Way': {2019: 0.5}, '105 Myrtle': {1999: 0.5, 2000: 0.5, 2014: 0.5, 2016: 0.5, 2017: 0.5, 2018: 0.5, 2019: 0.5}, '1052 Westview Way': {2019: 0.5}, '1080 Westview Way': {2019: 0.5}, '110 Parkland Plaza': {1986: 17.0, 1987: 7.0, 1988: 14.0, 1989: 11.0, 1990: 12.0, 1991: 10.0, 1992: 8.0, 1993: 9.0, 1998: 3.0, 1999: 5.0, 2000: 8.0, 2001: 9.0, 2002: 10.0, 2003: 9.0, 2004: 8.0, 2005: 5.0, 2006: 6.0, 2007: 6.0, 2008: 5.0, 2009: 4.0, 2010: 4.0, 2011: 3.0, 2012: 3.0, 2013: 5.0, 2014: 2.0, 2015: 2.0, 2016: 2.5, 2017: 1.6, 2018: 1.4, 2019: 1.2}, '1105 Westview Way': {2019: 0.5}, '1108 Westview Way': {2019: 0.5}, '1130 Westview Way': {2019: 0.5}, '1132 South Maple': {2003: 0.5}, '114 Myrtle': {2000: 0.5}, '1149 Southwood Ct': {2019: 0.5}, '116 LUELLA ST': {2014: 0.5, 2016: 0.5, 2017: 0.5, 2018: 0.5}, '1239 Westview Way': {2003: 0.5}, '131 Myrtle': {1999: 0.5, 2000: 0.5}, '170 Aprill': {1986: 1.0, 1987: 9.0, 1988: 
# ...

# %%
for key in res['110 Parkland Plaza']:
    print(key, res['110 Parkland Plaza'][key])
# Out:
# 1986 17.0
# 1987 7.0
# 1988 14.0
# 1989 11.0
# 1990 12.0
# 1991 10.0
# 1992 8.0
# 1993 9.0
# 1998 3.0
# 1999 5.0
# 2000 8.0
# 2001 9.0
# 2002 10.0
# 2003 9.0
# 2004 8.0
# 2005 5.0
# 2006 6.0
# 2007 6.0
# 2008 5.0
# 2009 4.0
# 2010 4.0
# 2011 3.0
# 2012 3.0
# 2013 5.0
# 2014 2.0
# 2015 2.0
# 2016 2.5
# 2017 1.6
# 2018 1.4
# 2019 1.2

# %%
# well_name_list = ['1024 Westview Way']
df = pd.DataFrame(res, columns=['Bore', 'Depth1', 'Depth2', 'LAT', 'LONG', '1986',
                                '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
                                '1996', '1997', '1998', '1999', '2000', '2001',
                                '2002', '2003', '2004','2005','2006','2007','2008', '2009', '2010','2011',
                                '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020'])
for well_name in well_name_list:
    var = gelman_data.loc[gelman_data['Bore'] == well_name].iloc[0]
    dict_t = {'Bore': var['Bore'], 'Depth1': var['Depth1'], 'Depth2': var['Depth2'], 'LAT': var['lat'],
              'LONG': var['lon']}
    if var['Depth1'] < 0:
        dict_t['Depth1'] = 'NaN'
    if var['Depth2'] < 0:
        dict_t['Depth2'] = 'NaN'
    for i in range(1986,2021):
        if res[var['Bore']].get(i) is not None:
            if res[var['Bore']].get(i) <= 0.5:
                dict_t[str(i)] = 0
            else:
                dict_t[str(i)] = res[var['Bore']].get(i)
        else:
            dict_t[str(i)] = 'NaN'
    df = df.append(dict_t, ignore_index=True)
print(df)
# Out:
#                   Bore Depth1 Depth2        LAT       LONG 1986 1987 1988  \
# 0    1021 Westview Way  260.0  268.0  42.269732 -83.807344  NaN  NaN  NaN
# 1    1024 Westview Way    NaN    NaN  42.269808 -83.809177  NaN  NaN  NaN
# 2    1049 Westview Way  272.0  280.0  42.269390 -83.807331  NaN  NaN  NaN
# 3           105 Myrtle   61.0   65.0  42.285462 -83.827411  NaN  NaN  NaN
# 4    1052 Westview Way  268.0  276.0  42.269322 -83.808887  NaN  NaN  NaN
# ..                 ...    ...    ...        ...        ...  ...  ...  ...
# 642               TW-6   54.0   64.0  42.278699 -83.802951  NaN  NaN  NaN
# 643               TW-7   65.0   75.0  42.275918 -83.803164  NaN  NaN  NaN
# 644               TW-8   59.5   69.5  42.276526 -83.803434  NaN  NaN  NaN
# 645               TW-9  105.0  115.0  42.280147 -83.806439  NaN  NaN  NaN
# 646       Varsity Ford    NaN    NaN  42.285902 -83.798445  NaN  NaN  NaN
#
#     1989 1990  ...    2011   2012   2013   2014   2015   2016   2017   2018  \
# ...

# %%
l = []
for i in range(1986, 2021):
    l.append(str(i))
l
# Out:
# ['1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020']

# %%
df.to_excel("./data.xlsx")
